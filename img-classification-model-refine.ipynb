# %% [markdown]
# # Image Classification Model Training

# %% [markdown]
# ### What TensorFlow trains
#
# TensorFlow doesn’t force one type of model — you can define your own.
# * But for image classification, the most common model is a Convolutional Neural Network (CNN).
# * CNNs are especially good at finding patterns in images (edges, textures, shapes).
# * TensorFlow + its high-level API Keras makes building CNNs very straightforward.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

print("Numpy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", plt.matplotlib.__version__)
print("TensorFlow:", tf.__version__)

from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Numpy: 2.3.2
# Pandas: 2.3.2
# Matplotlib: 3.10.6
# TensorFlow: 2.20.0

# %% [markdown]
# numpy is a library that provides easy calculations. matplotlib provides plots. pandas helps with loading, cleaning, exploring and preparing data in csv or tabular formats.
#
# Tensorflow is a ML/DL framework by google that can be used for simple tasks or neural networks of any level. keras is an api that is fully integrated with tf. If tf is an engine(Complex), keras is like a steering wheel/dashboard(easy to use). If tf is a toolbox, keras is an assistant that hands out the tools we need.

# %% [markdown]
# ### Verifying the path to the dataset

# %%
data_train_path = 'Fruits_Vegetables/train'
data_test_path = 'Fruits_Vegetables/test'
data_val_path = 'Fruits_Vegetables/validation'

# %% [markdown]
# ### setting the images in a similar size
#
# Neural networks expect all inputs to have the same shape.
#
# Why resizing matters
# * Consistency → CNN layers need fixed input dimensions.
# * Memory → Bigger images = more pixels = more computations.
# * Speed → Smaller images train faster (but might lose detail).

# %%
img_width = 180
img_height = 180

# %% [markdown]
# ### Loading and batching the training dataset

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 3115 files belonging to 36 classes.

# %% [markdown]
# ##### tf.keras.utils.image_dataset_from_directory()
#
# This function creates a dataset from images stored in folders.
# it assumes:
#
#     data_train_path/
#         apple/
#             apple1.jpg
#             apple2.jpg
#         banana/
#             banana1.jpg
#             banana2.jpg
#         tomato/
#             tomato1.jpg
#             tomato2.jpg
#
# Each subfolder name becomes a label automatically.
# * apple/ → class 0
# * banana/ → class 1
# * tomato/ → class 2
#
# ##### shuffle=True
#
# Randomly shuffles the images before batching.
#
# Important so the model doesn’t see all apples first, then all bananas — it learns better when classes are mixed.
#
# ##### batch_size=32
#
# Groups images into batches of 32.
#
# Instead of training one image at a time (too slow), the model sees 32 at once, processes them in parallel, and updates weights after each batch.
#
# ##### validation_split=False
#
# By default, this function can split your dataset into training and validation sets.
#
# Since it’s set to False, it means you’re not splitting here — all images in this directory will be used for training.

# %% [markdown]
# ### The data Classes

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %% [markdown]
# ### Loading and batching the Validation dataset

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    image_size=(img_height, img_width),
    batch_size=32,
    shuffle=False,
    validation_split=False
)
# Out:
# Found 351 files belonging to 36 classes.

# %% [markdown]
# ### Loading and batching the testing dataset

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
data_test_path,
    image_size=(img_height,img_width),
    shuffle=False,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# ### Printing a sample from the training dataset

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %% [markdown]
# ##### plt.figure(figsize=(10,10))
# * Creates a blank figure with size 10×10 inches (so the grid of images isn’t tiny).
#
# ##### for image, labels in data_train.take(1):
# * grabs 1 batch of data from your dataset.
# Since your batch size is 32, this batch has 32 images + 32 labels.
#
# The loop unpacks that batch into:
# * image → the 32 images (a tensor).
# * labels → the 32 class labels (numbers like 0, 1, 2...).
#
# for i in range(9): - You only want to show the first 9 images from that batch.
#
# plt.subplot(3,3,i+1) - Makes a grid of 3 rows × 3 columns.
# i+1 ensures it fills the subplots from 1 to 9.
#
# ##### plt.imshow(image[i].numpy().astype('uint8'))
# * Takes the i-th image from the batch.
# * .numpy() converts it from a TensorFlow tensor → NumPy array (so matplotlib can use it).
# * .astype('uint8') makes sure pixel values are integers between 0–255 (standard image format).
# * Displays the image.
#
# ##### plt.title(data_cat[labels[i]])
# * labels[i] is the numeric class (e.g., 0).
# * data_cat is likely a list of class names (like ["apple", "banana", "tomato"]).
# * So data_cat[0] = "apple" → gives you a human-readable label for the title.
#
# plt.axis('off') - Removes the x/y axis ticks (since you don’t need them for images).

# %% [markdown]
# ### Building the Sequential model

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# Below is a way to make the training more robust. This way, every epoch, the model sees slightly different versions of the same image.

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

# %% [markdown]
# This is a CNN classifier:
#
# * First layers → extract features (edges → shapes → textures).
# * Flatten + Dense → interpret those features.
# * Final Dense → output class scores.

# %%
model = Sequential([ #stacking layers one after another in a straight line.
    data_augmentation, #data augmentation layer
    layers.Rescaling(1./255), #divides every pixel by 255 → normalizes the input
    layers.Conv2D(16, 3, padding='same', activation='relu'), #a convolutional layer, which looks for patterns in the image.
    layers.MaxPooling2D(), #This reduces size, keeps important features, and makes the model faster
    layers.Conv2D(32,3, padding='same',activation='relu'), #Now with 32 filters → 
    layers.MaxPooling2D(), #deeper patterns (like corners, blobs).
    layers.Conv2D(64, 3, padding='same', activation='relu'), #64 filters
    layers.MaxPooling2D(), #complex features (like shapes, textures)
    layers.Flatten(), #2D feature flattens to 1D vector - 10×10×64 tensor turns to a vector of 6400 values
    layers.Dropout(0.2), #Randomly turns off 20% of neurons during training - Prevents overfitting
    layers.Dense(128), # A fully connected (Dense) layer with 128 neurons - decision-making part
    layers.Dense(len(data_cat)) #Final output layer
])

# %% [markdown]
# model.compile() is basically telling Keras:
#
# * How to measure error → loss function
# * How to fix errors → optimizer
# * What to track for performance → metrics
#
# After this, your model is ready for model.fit() to actually train on your images.

# %%
model.compile(
    optimizer='adam', #decides how the model updates its weights during training
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
    #Loss function measures how wrong the model’s predictions are compared to true labels
    #SparseCategoricalCrossentropy is used when: more than 2 classes or labels are integers (like 0, 1, 2…)
    #from_logits=True tells TF: last layer doesn’t have softmax activation. outputs are raw scores (logits)
    metrics=['accuracy'] #what you monitor during training.
    #'accuracy' means Keras will report the percentage of correct predictions after each epoch.
)

# %% [markdown]
# ### Training Process
#
# model.fit() is where the model actually learns from your images.
#
# Training = improving weights
#
# Validation = monitoring generalization
#
# Epochs = how many times you cycle through the data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)
#EarlyStopping to stop when validation loss stops improving
epochs_size = 100
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size, callbacks=[callback])
# Out:
# Epoch 1/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 52s 497ms/step - accuracy: 0.0944 - loss: 3.3229 - val_accuracy: 0.2479 - val_loss: 2.6024
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 40s 404ms/step - accuracy: 0.2552 - loss: 2.5892 - val_accuracy: 0.3875 - val_loss: 1.9790
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 414ms/step - accuracy: 0.3316 - loss: 2.2828 - val_accuracy: 0.4387 - val_loss: 1.8072
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 422ms/step - accuracy: 0.3920 - loss: 2.0760 - val_accuracy: 0.5385 - val_loss: 1.5895
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 418ms/step - accuracy: 0.4372 - loss: 1.9062 - val_accuracy: 0.6268 - val_loss: 1.3508
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 420ms/step - accuracy: 0.4610 - loss: 1.8345 - val_accuracy: 0.6325 - val_loss: 1.2848
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 43s 435ms/step - accuracy: 0.4831 - loss: 1.7352 - val_accuracy: 0.6040 - val_loss: 1.3450
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 78s 396ms/step - accuracy: 0.5149 - loss: 1.6656 - val_accuracy: 0.7322 - val_loss: 1.0312
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 412ms/step - accuracy: 0.5197 - loss: 1.5997 - val_accuracy: 0.6353 - val_loss: 1.1879
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 412ms/step - accuracy: 0.5451 - loss: 1.5635 - val_accuracy: 0.7236 - val_loss: 1.0050
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 413ms/step - accuracy: 0.5547 - loss: 1.4949 - val_accuracy: 0.6923 - val_loss: 1.0800
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 429ms/step - accuracy: 0.5653 - loss: 1.4466 - val_accuracy: 0.6838 - val_loss: 1.0719
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 413ms/step - accuracy: 0.5778 - loss: 1.4044 - val_accuracy: 0.7493 - val_loss: 0.8938
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 416ms/step - accuracy: 0.5843 - loss: 1.3704 - val_accuracy: 0.7607 - val_loss: 0.9072
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 415ms/step - accuracy: 0.6077 - loss: 1.3134 - val_accuracy: 0.6895 - val_loss: 1.1528
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 44s 452ms/step - accuracy: 0.6173 - loss: 1.2697 - val_accuracy: 0.7179 - val_loss: 1.0350
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 47s 475ms/step - accuracy: 0.6299 - loss: 1.2538 - val_accuracy: 0.7066 - val_loss: 1.0331
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 45s 457ms/step - accuracy: 0.6491 - loss: 1.1493 - val_accuracy: 0.8291 - val_loss: 0.7510
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 48s 489ms/step - accuracy: 0.6655 - loss: 1.1139 - val_accuracy: 0.7607 - val_loss: 0.8956
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 47s 474ms/step - accuracy: 0.6774 - loss: 1.0511 - val_accuracy: 0.7407 - val_loss: 1.0273
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 51s 522ms/step - accuracy: 0.6896 - loss: 1.0569 - val_accuracy: 0.8405 - val_loss: 0.6869
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 45s 446ms/step - accuracy: 0.6803 - loss: 1.0445 - val_accuracy: 0.7578 - val_loss: 0.8763
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 46s 465ms/step - accuracy: 0.6828 - loss: 1.0259 - val_accuracy: 0.8405 - val_loss: 0.6745
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 46s 460ms/step - accuracy: 0.7082 - loss: 0.9409 - val_accuracy: 0.8319 - val_loss: 0.7005
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 47s 475ms/step - accuracy: 0.7095 - loss: 0.9388 - val_accuracy: 0.8291 - val_loss: 0.6636
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 47s 472ms/step - accuracy: 0.7220 - loss: 0.9232 - val_accuracy: 0.8376 - val_loss: 0.6979
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 45s 451ms/step - accuracy: 0.7178 - loss: 0.8993 - val_accuracy: 0.8348 - val_loss: 0.6676
# Epoch 28/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 406ms/step - accuracy: 0.7355 - loss: 0.8928 - val_accuracy: 0.8490 - val_loss: 0.5847
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 40s 411ms/step - accuracy: 0.7429 - loss: 0.8300 - val_accuracy: 0.8405 - val_loss: 0.6259
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 44s 446ms/step - accuracy: 0.7406 - loss: 0.8251 - val_accuracy: 0.8803 - val_loss: 0.5384
# Epoch 31/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 81s 433ms/step - accuracy: 0.7464 - loss: 0.8422 - val_accuracy: 0.8689 - val_loss: 0.5686
# Epoch 32/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 44s 447ms/step - accuracy: 0.7746 - loss: 0.7464 - val_accuracy: 0.8661 - val_loss: 0.6110
# Epoch 33/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 414ms/step - accuracy: 0.7711 - loss: 0.7307 - val_accuracy: 0.8718 - val_loss: 0.6640
# Epoch 34/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 412ms/step - accuracy: 0.7634 - loss: 0.7776 - val_accuracy: 0.8946 - val_loss: 0.4955
# Epoch 35/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 417ms/step - accuracy: 0.7586 - loss: 0.7564 - val_accuracy: 0.9031 - val_loss: 0.5207
# Epoch 36/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 417ms/step - accuracy: 0.7624 - loss: 0.7187 - val_accuracy: 0.8718 - val_loss: 0.5659
# Epoch 37/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 45s 452ms/step - accuracy: 0.7769 - loss: 0.7030 - val_accuracy: 0.8832 - val_loss: 0.5357
# Epoch 38/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 43s 433ms/step - accuracy: 0.7881 - loss: 0.6796 - val_accuracy: 0.8632 - val_loss: 0.5122
# Epoch 39/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 424ms/step - accuracy: 0.7820 - loss: 0.6579 - val_accuracy: 0.8632 - val_loss: 0.5840

# %%
epochs_actual = range(len(history.history['accuracy']))
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_actual, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_actual, history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_actual, history.history['loss'], label='Training Loss')
plt.plot(epochs_actual, history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %% [markdown]
# ### Predicting values

# %%
image = 'eggplant.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is eggplant with accuracy of 94.69

# %%
model.save('Image_classify.keras')
